# %% [markdown]
# <h1>Tutorial 1:</h1>
#
# (1) (20 points) use the jupyter notebook to print the following information: Your student ID, your name, and your current time.

# %%
import datetime
StudentID = '58434290'
Name = "ZENG Jiekai"
x = datetime.datetime.now()
print("Now the time is", end = ' ')
print(x)
print("my student ID is " + StudentID + ", my name is " + Name + ".")
# Out:
# Now the time is 2024-01-17 02:15:17.448772
# my student ID is 58434290, my name is ZENG Jiekai.

# %% [markdown]
# (2) (20 points) put the information above into a pandas dataframe (the table in step 3)

# %%
import pandas as pd
mytable = pd.DataFrame(columns=['id', 'name', 'time'])
mytable.loc[0] = [StudentID, Name, x]
mytable
# Out:
#          id         name                       time
# 0  58434290  ZENG Jiekai 2024-01-17 02:15:17.448772

# %% [markdown]
# (3) (60 points) after a few seconds, add the second row of your id, name, time

# %%
mytable.loc[1] = [StudentID, Name, datetime.datetime.now()]
mytable
# Out:
#          id         name                       time
# 0  58434290  ZENG Jiekai 2024-01-17 02:15:17.448772
# 1  58434290  ZENG Jiekai 2024-01-17 02:20:24.776385
